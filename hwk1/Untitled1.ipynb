# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("test_spark") \
    .master("local[*]") \
    .getOrCreate()

print("Spark version:", spark.version)

df = spark.range(5)
df.show()

spark.stop()
# Out:
# Spark version: 3.5.6
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+
